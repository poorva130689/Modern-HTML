# %% [markdown]
# 1.List out the features of HTML5.
# -      Features of HTML5:-
#
#
# * New elements ,attributes,support for multimedia; better error handling.
#
# *  Enhanced forms with new input types.
#
#
# *   Local storage for offline use.
# * New tags like <article> <aside> <figure>
#
#
# *  Graphics and animation with<canvas> and <svg>

# %% [markdown]
# 2. What are HTML Entities? List out 5 commonly used HTML entities.
# -       HTML entities are special codes used in HTML to represents characters that cannot be directly inserted into the code or have specific meanings in HTML syntax.
#
# # 5 commonly used HTML entities:-

# %%
1.&lt;
2.&gt;
3. &amp;
4.&copy;
5.&nbsp;

# %% [markdown]
# 3.Define accessibility in the context of web development . Discuss why it's essential to create accessible websites and how it benefits different user groups.
# - In web development ,accessibility refers to designing and developing websites that can be use
# d by people with disabilities,including visual,auditory,motor,and cognitive impairments.
#
#
# # Why it's essential:-
#
#
# * Inclusivity and equal Access
# * Legal and ethical consideration
#
#
# * Improve user experience
# *  Wider Audience  reach
#
#
#
#
# # Benefits for different user groups:-
#
#
# * People with disabilities
# *  Older adults

# %% [markdown]
# 4. List any 5 ways which helps us in improving the accessibility of HTML
# -     1. Use semantic HTML Tags.
#       2. Provide alt text for images.
#       3.Ensure keyboard navigability
#       4 Descriptive Link Text
#       5. Color contrast.

# %% [markdown]
# 5.Create a web page that highlights the features of HTML5 .Use appropriate semantic tags to structure the content and showcase at least three key features of HTML5 with explanations.
# -

# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width,initial-scale=1.0"
<title>HTML5 features</title>
</head>
<body>
<header>
        <h1>HTML5 Features</h1>
        </header>
        <main>
        <section class="feature">
        <h2>semantic element</h2>
        <p> HTML5 introduce a new set of semantic elements to give content meaning and structure.examples include<article>, <aside>,<header>,and <footer>.</p>
        </section>
        </main>
        <footer>
             <p>&copy; 2025 HTML 5 Features</p>
             </footer>
             </body>
             </html>

# %% [markdown]
# 6.Create a simple web page which has a table .The table must have 2 columns HTML and HTML5 .The table should include a minimum of three rows describing the differences between HTML and HTML5.
# -

# %%
<!DOCTYPEhtml>
<html>
<head>
<title>HTML vs HTML5</title
</head>
<body>
<h1>HTML vs HTML5</h1>
<table border="1">
<tr>
<th>HTML</th>
<th>HTML5</>
</tr>
<tr>
<td>Focus primarilly on structure and content.</td>
<td>Adds more semantic elements for better structuring and meaning.</td>
</tr>
<tr>
<td> Requires external media like images and videos.</td>
<td> Supports embedding media directly within the HTML5 file using &lt; ,video&gt; &lt; tags</td>
</tr>
<tr>
<td>Older version, less feature-rich.</td>
<td>Modern version,more features and capabilities.</td>
</tr>
</table>
</body>
</html>
